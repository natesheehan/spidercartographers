# %%
#get the current working directory 
import os

os.getcwd()
# Out:
# '/Users/Hussein/Documents/Code Repos/spidercartographers/Scripts'

# %%
#importing pandas
import pandas as pd

# %%
#reading in the cleaned transport csv
cleaned = pd.read_csv("Data/cleaned_transport.csv")

# %%
#checking for NaNs
cleaned.isna().sum()
# Out:
# MSOA                      0
# work_from_home_perc       0
# underground_metro_perc    0
# train_perc                0
# bus_perc                  0
# motorcycle_perc           0
# bicycle_perc              0
# on_foot_perc              0
# other_perc                0
# car_perc                  0
# dtype: int64

# %%
#checking the count of each variable
cleaned.count()
# Out:
# MSOA                      7201
# work_from_home_perc       7201
# underground_metro_perc    7201
# train_perc                7201
# bus_perc                  7201
# motorcycle_perc           7201
# bicycle_perc              7201
# on_foot_perc              7201
# other_perc                7201
# car_perc                  7201
# dtype: int64

# %%
#filling the nas in place
cleaned = cleaned.fillna(0)

# %%
#describing the data 
cleaned.describe()
# Out:
#        work_from_home_perc  underground_metro_perc   train_perc     bus_perc  \
# count          7201.000000             7201.000000  7201.000000  7201.000000
# mean             10.381327                3.366972     4.705109     7.309413
# std               4.826474                8.826858     6.114003     6.356014
# min               2.826552                0.000000     0.052521     0.173671
# 25%               7.034728                0.067981     1.024378     2.491103
# 50%               8.896122                0.154979     2.332223     5.378328
# 75%              12.367384                0.538761     5.741775    10.130410
# max              37.591728               55.726092    46.028513    45.517755
#
#        motorcycle_perc  bicycle_perc  on_foot_perc   other_perc     car_perc
# count      7201.000000   7201.000000   7201.000000  7201.000000  7201.000000
# mean          0.775569      2.681102      9.768108     0.498831    60.009764
# std           0.402502      2.609434      6.457069     0.308716    16.491918
# min           0.024248      0.080678      1.495132     0.034176     3.051202
# 25%           0.505051      1.144674      5.330564     0.330231    54.508453
# 50%           0.696970      1.879947      7.910112     0.437788    65.107577
# 75%           0.959581      3.293135     12.098765     0.579990    71.104748
# max           4.012672     33.739166     51.324141     5.922062    84.167759

# %%
#checking the types of the data
cleaned.dtypes
# Out:
# MSOA                       object
# work_from_home_perc       float64
# underground_metro_perc    float64
# train_perc                float64
# bus_perc                  float64
# motorcycle_perc           float64
# bicycle_perc              float64
# on_foot_perc              float64
# other_perc                float64
# car_perc                  float64
# dtype: object

# %%
# #plotting all the distributions of the each of the variables
# #looks like most of them are positively skewed and could be amenable to log transformation

# import matplotlib.pyplot as plt
# import seaborn as sns

# f, axes = plt.subplots(4,5, figsize = (20,20), sharex=False)


# sns.distplot(cleaned["Bus_stops"], ax=axes[0,0])
# sns.distplot(cleaned["Train_stations"], ax=axes[0,1])
# sns.distplot(cleaned["metro_stations"], ax=axes[0,2])
# sns.distplot(cleaned["HH_owning_cars_perc"], ax=axes[0,3])
# sns.distplot(cleaned["work_from_home_perc"], ax=axes[0,4])
# sns.distplot(cleaned["underground_metro_perc"], ax=axes[1,0])
# sns.distplot(cleaned["train_perc"], ax=axes[1,1])
# sns.distplot(cleaned["bus_perc"], ax=axes[1,2])
# sns.distplot(cleaned["taxi_perc"], ax=axes[1,4])
# sns.distplot(cleaned["motorcycle_perc"], ax=axes[2,0])
# sns.distplot(cleaned["bicycle_perc"], ax=axes[2,1])
# sns.distplot(cleaned["on_foot_perc"], ax=axes[2,2])
# sns.distplot(cleaned["other_perc"], ax=axes[2,3])
# sns.distplot(cleaned["avg_time_car"], ax=axes[2,4])
# sns.distplot(cleaned["avg_time_bus"], ax=axes[3,0])
# sns.distplot(cleaned["avg_time_rail"], ax=axes[3,1])
# sns.distplot(cleaned["car_perc"], ax=axes[3,2])

# %%
#before transforming drop the MSOA column
#create a new dataframe so retain the original MSOA column
cleaned1 = cleaned.drop(["MSOA"], axis = 1 )

# %%
#cleaning them by log transformation

import numpy as np

for column in cleaned1.columns:
    try:
        cleaned1[column] = np.log10(cleaned1[column])
    except (ValueError, AttributeError):
        pass
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/series.py:679: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
#log does not work with 0's for which there were many
#therefore replace any infinity values with 0 again afterwards
cleaned1 = cleaned1.replace([np.inf, -np.inf], 0)

# %%
# #plot the resulting distributions using the same as before
# f, axes = plt.subplots(4,5, figsize = (20,20), sharex=False)


# sns.distplot(cleaned1["Bus_stops"], ax=axes[0,0])
# sns.distplot(cleaned1["Train_stations"], ax=axes[0,1])
# sns.distplot(cleaned1["metro_stations"], ax=axes[0,2])
# sns.distplot(cleaned1["HH_owning_cars_perc"], ax=axes[0,3])
# sns.distplot(cleaned1["work_from_home_perc"], ax=axes[0,4])
# sns.distplot(cleaned1["underground_metro_perc"], ax=axes[1,0])
# sns.distplot(cleaned1["train_perc"], ax=axes[1,1])
# sns.distplot(cleaned1["bus_perc"], ax=axes[1,2])
# sns.distplot(cleaned1["taxi_perc"], ax=axes[1,4])
# sns.distplot(cleaned1["motorcycle_perc"], ax=axes[2,0])
# sns.distplot(cleaned1["bicycle_perc"], ax=axes[2,1])
# sns.distplot(cleaned1["on_foot_perc"], ax=axes[2,2])
# sns.distplot(cleaned1["other_perc"], ax=axes[2,3])
# sns.distplot(cleaned1["avg_time_car"], ax=axes[2,4])
# sns.distplot(cleaned1["avg_time_bus"], ax=axes[3,0])
# sns.distplot(cleaned1["avg_time_rail"], ax=axes[3,1])
# sns.distplot(cleaned1["car_perc"], ax=axes[3,2])

# %%
#add the MSOA value back in
cleaned1["MSOA"] = cleaned["MSOA"]

# %%
#check to see what the outcome looks like
cleaned1
# Out:
#       work_from_home_perc  underground_metro_perc  train_perc  bus_perc  \
# 0                1.165836                1.264601    0.735091  0.743364
# 1                0.806246                1.194798    0.914479  1.168329
# 2                0.838584                1.106468    1.297765  1.026087
# 3                0.804009                1.006336    1.138330  0.998783
# 4                0.798410                1.093636    1.089723  1.178300
# ...                   ...                     ...         ...       ...
# 7196             0.907075               -1.673850    0.111480  0.530270
# 7197             1.125100               -0.827692   -0.079504  0.552519
# 7198             1.391915               -0.969183   -0.468581  0.252666
# 7199             0.782284               -1.192382    0.695985  0.903369
# 7200             0.792005               -0.631241    0.748970  0.951958
#
#       motorcycle_perc  bicycle_perc  on_foot_perc  other_perc  car_perc  \
# 0           -0.337459      0.705724      1.659371   -0.067098  0.484471
# 1           -0.052729      0.123362      0.669306   -0.315970  1.670428
# 2           -0.165598     -0.054900      0.771175   -0.334741  1.617429
# 3            0.035299      0.123721      0.829495   -0.342119  1.694387
# 4           -0.037185      0.200176      0.743154   -0.777548  1.655154
# ...               ...           ...           ...         ...       ...
# 7196        -0.142371      0.408935      0.980327   -0.443401  1.863213
# 7197        -0.322542      0.176629      0.603671   -0.259491  1.877230
# 7198        -0.242184     -0.006971      0.602914   -0.367123  1.825654
# 7199        -0.669503      0.529154      1.275473   -0.327080  1.759280
# 7200        -0.853090      0.601755      1.431717   -0.112727  1.666301
#
#            MSOA
# 0     E02000001
# 1     E02000002
# 2     E02000003
# 3     E02000004
# 4     E02000005
# ...         ...
# 7196  W02000419
# 7197  W02000420
# 7198  W02000421
# 7199  W02000422
# 7200  W02000423
#
# [7201 rows x 10 columns]

# %%
#output the results to a csv
cleaned1.to_csv("Data/transport_log_transform.csv", index=False)

# %%
#running the next stage which is the standardisation
#drop the MSOA value again

cleaned1.drop(["MSOA"], axis = 1, inplace = True)

# %%
#get the columns names to then re-add to the numpy array
column_names = list(cleaned1.columns)

# %%
#use the preprocessing function which does a normal standardisation


import sklearn.preprocessing as preprocessing

#this takes arguments: X ,axis = 0, with_mean = True, with_std = True, copy = True
#X is the data to centre and scale
#axs: int (0 by default) - axis used to compute means and Std along, if 0  independentky
#standardise each feature, other (if 1) standardize each sample
#with_mean: boolean, True by default, if true centre the data before scaling
#with_std: boolean, True by default, if True scale the data to unit variance
#copy: boolean, optional, default True, set to False to perform inplace row normalisation and avoid a copy

#NaNs are treated as missing values: disregarded

scaled = preprocessing.scale(cleaned1) # add your dataframe name here

#this creates a numpy array
scaled
# Out:
# array([[ 1.06377697,  2.01944168,  0.68684241, ...,  2.95630581,
#          1.39123922, -6.66446346],
#        [-0.9690509 ,  1.93829976,  1.04141872, ..., -0.96657802,
#          0.18872816, -0.4133832 ],
#        [-0.78623504,  1.83562063,  1.79902109, ..., -0.56295053,
#          0.09803189, -0.69273914],
#        ...,
#        [ 2.34184105, -0.57721205, -1.69233298, ..., -1.22964176,
#         -0.05843267,  0.40479716],
#        [-1.10451186, -0.8366686 ,  0.60954507, ...,  1.43520686,
#          0.13504734,  0.05494583],
#        [-1.04955457, -0.18437249,  0.71427573, ...,  2.05428482,
#          1.17076835, -0.43513751]])

# %%
#transform the numpy array back into a dataframe
log_then_normal = pd.DataFrame(scaled)

# %%
#add back the columns names stored before

log_then_normal.columns = column_names

# %%
#add back the MSOA columns
log_then_normal["MSOA"] = cleaned["MSOA"]

# %%
#write the resulting output to a csv
log_then_normal.to_csv("Data/transport_log_then_normal.csv", index=False)

# %%
scaled
# Out:
# array([[ 1.06377697,  2.01944168,  0.68684241, ...,  2.95630581,
#          1.39123922, -6.66446346],
#        [-0.9690509 ,  1.93829976,  1.04141872, ..., -0.96657802,
#          0.18872816, -0.4133832 ],
#        [-0.78623504,  1.83562063,  1.79902109, ..., -0.56295053,
#          0.09803189, -0.69273914],
#        ...,
#        [ 2.34184105, -0.57721205, -1.69233298, ..., -1.22964176,
#         -0.05843267,  0.40479716],
#        [-1.10451186, -0.8366686 ,  0.60954507, ...,  1.43520686,
#          0.13504734,  0.05494583],
#        [-1.04955457, -0.18437249,  0.71427573, ...,  2.05428482,
#          1.17076835, -0.43513751]])

# %% [markdown]
# ## range standardisation

# %%
#transform df to np array
cleaned_array = cleaned1.values

#range standardisation
min_max_scaler = preprocessing.MinMaxScaler()
min_max_scaled = min_max_scaler.fit_transform(cleaned_array)
# transform to dataframe
range_standardized = pd.DataFrame(min_max_scaled, columns=column_names)
range_standardized
# Out:
#       work_from_home_perc  underground_metro_perc  train_perc  bus_perc  \
# 0                0.635840                0.869858    0.684665  0.621735
# 1                0.315872                0.850990    0.745625  0.797453
# 2                0.344648                0.827113    0.875875  0.738637
# 3                0.313882                0.800047    0.821695  0.727347
# 4                0.308900                0.823645    0.805177  0.801575
# ...                   ...                     ...         ...       ...
# 7196             0.405591                0.075570    0.472746  0.533623
# 7197             0.599592                0.304294    0.407845  0.542823
# 7198             0.837007                0.266048    0.275627  0.418837
# 7199             0.294551                0.205715    0.671375  0.687895
# 7200             0.303201                0.357396    0.689381  0.707986
#
#       motorcycle_perc  bicycle_perc  on_foot_perc  other_perc  car_perc
# 0            0.575936      0.686268      0.966821    0.624982  0.000000
# 1            0.704265      0.464110      0.322098    0.513816  0.823196
# 2            0.653394      0.396107      0.388434    0.505432  0.786408
# 3            0.743940      0.464247      0.426412    0.502136  0.839826
# 4            0.711271      0.493413      0.370187    0.307639  0.812594
# ...               ...           ...           ...         ...       ...
# 7196         0.663863      0.573050      0.524632    0.456895  0.957011
# 7197         0.582659      0.484430      0.279357    0.539044  0.966741
# 7198         0.618877      0.414390      0.278863    0.490967  0.930941
# 7199         0.426283      0.618911      0.716829    0.508853  0.884869
# 7200         0.343540      0.646606      0.818575    0.604600  0.820331
#
# [7201 rows x 9 columns]

# %%
#then add the MSOA column
range_standardized["MSOA"] = cleaned["MSOA"]

range_standardized
# Out:
#       work_from_home_perc  underground_metro_perc  train_perc  bus_perc  \
# 0                0.635840                0.869858    0.684665  0.621735
# 1                0.315872                0.850990    0.745625  0.797453
# 2                0.344648                0.827113    0.875875  0.738637
# 3                0.313882                0.800047    0.821695  0.727347
# 4                0.308900                0.823645    0.805177  0.801575
# ...                   ...                     ...         ...       ...
# 7196             0.405591                0.075570    0.472746  0.533623
# 7197             0.599592                0.304294    0.407845  0.542823
# 7198             0.837007                0.266048    0.275627  0.418837
# 7199             0.294551                0.205715    0.671375  0.687895
# 7200             0.303201                0.357396    0.689381  0.707986
#
#       motorcycle_perc  bicycle_perc  on_foot_perc  other_perc  car_perc  \
# 0            0.575936      0.686268      0.966821    0.624982  0.000000
# 1            0.704265      0.464110      0.322098    0.513816  0.823196
# 2            0.653394      0.396107      0.388434    0.505432  0.786408
# 3            0.743940      0.464247      0.426412    0.502136  0.839826
# 4            0.711271      0.493413      0.370187    0.307639  0.812594
# ...               ...           ...           ...         ...       ...
# 7196         0.663863      0.573050      0.524632    0.456895  0.957011
# 7197         0.582659      0.484430      0.279357    0.539044  0.966741
# 7198         0.618877      0.414390      0.278863    0.490967  0.930941
# 7199         0.426283      0.618911      0.716829    0.508853  0.884869
# 7200         0.343540      0.646606      0.818575    0.604600  0.820331
#
#            MSOA
# 0     E02000001
# 1     E02000002
# 2     E02000003
# 3     E02000004
# 4     E02000005
# ...         ...
# 7196  W02000419
# 7197  W02000420
# 7198  W02000421
# 7199  W02000422
# 7200  W02000423
#
# [7201 rows x 10 columns]

# %%
range_standardized.to_csv("Data/transport_log_then_range.csv", index=False)

# %% [markdown]
# ## interdecile

# %%
from sklearn.preprocessing import RobustScaler

# we change the range because the default is iqr (0.25 - 0.75)
idr = RobustScaler(quantile_range = (0.1,0.9))

# Transform the 'yj_transformed' df
idr_mat = idr.fit_transform(cleaned_array)
idr_mat
# Out:
# array([[ 3.21187499, 24.13014004,  1.01455196, ...,  5.9247578 ,
#          0.89635679, -7.12131673],
#        [-2.11947913, 23.28754423,  1.51002436, ..., -1.78147357,
#          0.1314417 , -0.76724877],
#        [-1.6400209 , 22.22130133,  2.56867115, ..., -0.98857555,
#          0.07374997, -1.05120715],
#        ...,
#        [ 6.56376342, -2.83409112, -2.31002367, ..., -2.29824393,
#         -0.02577685,  0.06441127],
#        [-2.47474304, -5.5283458 ,  0.90653939, ...,  2.93666512,
#          0.09729543, -0.29120392],
#        [-2.33061045,  1.24524243,  1.0528863 , ...,  4.15280054,
#          0.75611567, -0.78936148]])

# %%
# transform to a df
idr_scaled = pd.DataFrame(idr_mat, columns=column_names)
idr_scaled
# Out:
#       work_from_home_perc  underground_metro_perc  train_perc  bus_perc  \
# 0                3.211875               24.130140    1.014552  0.068626
# 1               -2.119479               23.287544    1.510024  2.361978
# 2               -1.640021               22.221301    2.568671  1.594357
# 3               -2.152636               21.012597    2.128309  1.447008
# 4               -2.235657               22.066407    1.994055  2.415786
# ...                   ...                     ...         ...       ...
# 7196            -0.624563              -11.340200   -0.707881 -1.081348
# 7197             2.607917               -1.126144   -1.235384 -0.961280
# 7198             6.563763               -2.834091   -2.310024 -2.579455
# 7199            -2.474743               -5.528346    0.906539  0.932101
# 7200            -2.330610                1.245242    1.052886  1.194316
#
#       motorcycle_perc  bicycle_perc  on_foot_perc  other_perc  car_perc
# 0           -0.378707      1.382841      5.924758    0.896357 -7.121317
# 1            0.218113     -0.483132     -1.781474    0.131442 -0.767249
# 2           -0.018472     -1.054311     -0.988576    0.073750 -1.051207
# 3            0.402629     -0.481981     -0.534634    0.051074 -0.638882
# 4            0.250695     -0.237010     -1.206674   -1.287228 -0.849081
# ...               ...           ...           ...         ...       ...
# 7196         0.030215      0.431886      0.639373   -0.260220  0.265646
# 7197        -0.347440     -0.312457     -2.292347    0.305034  0.340745
# 7198        -0.179002     -0.900740     -2.298244   -0.025777  0.064411
# 7199        -1.074700      0.817085      2.936665    0.097295 -0.291204
# 7200        -1.459514      1.049709      4.152801    0.756116 -0.789361
#
# [7201 rows x 9 columns]

# %%
idr_scaled["MSOA"] = cleaned["MSOA"]

idr_scaled.head()
# Out:
#    work_from_home_perc  underground_metro_perc  train_perc  bus_perc  \
# 0             3.211875               24.130140    1.014552  0.068626
# 1            -2.119479               23.287544    1.510024  2.361978
# 2            -1.640021               22.221301    2.568671  1.594357
# 3            -2.152636               21.012597    2.128309  1.447008
# 4            -2.235657               22.066407    1.994055  2.415786
#
#    motorcycle_perc  bicycle_perc  on_foot_perc  other_perc  car_perc  \
# 0        -0.378707      1.382841      5.924758    0.896357 -7.121317
# 1         0.218113     -0.483132     -1.781474    0.131442 -0.767249
# 2        -0.018472     -1.054311     -0.988576    0.073750 -1.051207
# 3         0.402629     -0.481981     -0.534634    0.051074 -0.638882
# 4         0.250695     -0.237010     -1.206674   -1.287228 -0.849081
#
#         MSOA
# 0  E02000001
# 1  E02000002
# 2  E02000003
# 3  E02000004
# 4  E02000005

# %%
#save to csv
idr_scaled.to_csv('Data/transport_log_then_idr.csv')

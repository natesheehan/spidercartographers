# %% [markdown]
# ## clustering python notebook

# %%
import os 
os.getcwd()
# Out:
# '/Users/Hussein/Documents/Code Repos/spidercartographers/Scripts'

# %%
# importing libraries required
import pandas as pd
import plotly.express as px
import sklearn.preprocessing as preprocessing
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import random
from sklearn.cluster import AgglomerativeClustering
from sklearn import neighbors
import numpy as np

# run this command too - just to allow more data to be displayed than default
pd.set_option('display.max_rows', 200)
# this one ensures graphs properly display in the notebook
# %matplotlib inline

# %%
#put the data into a dataframe
yj = pd.read_csv('Data/yeojohnson_zscore_st.csv')
#check that is has been read correctly
yj
# Out:
#       Unnamed: 0       MSOA  yj_Bus_stops  yj_Train_stations  \
# 0              0  E02000001      3.625940           1.820241
# 1              1  E02000002     -0.963892          -0.579537
# 2              2  E02000003     -1.131653          -0.579537
# 3              3  E02000004     -1.619346          -0.579537
# 4              4  E02000005     -1.980026          -0.579537
# ...          ...        ...           ...                ...
# 7196        7196  W02000419      1.371322          -0.579537
# 7197        7197  W02000420      2.438483          -0.579537
# 7198        7198  W02000421      2.934894          -0.579537
# 7199        7199  W02000422      0.794516          -0.579537
# 7200        7200  W02000423      0.949971           1.705764
#
#       yj_metro_stations  yj_HH_owning_cars_perc  yj_work_from_home_perc  \
# 0              3.529935               -2.078686                1.094545
# 1             -0.283298               -1.009171               -1.009040
# 2             -0.283298               -0.623687               -0.780242
# 3             -0.283298               -0.106580               -1.025167
# 4             -0.283298               -0.796578               -1.065720
# ...                 ...                     ...                     ...
# 7196          -0.283298                0.101249               -0.322619
# 7197          -0.283298                1.144891                0.902061
# 7198           3.529935                1.093962                1.984056
# 7199          -0.283298                0.433334               -1.183888
# 7200          -0.283298               -0.993786               -1.112405
#
#       yj_underground_metro_perc  yj_train_perc  yj_bus_perc  ...  \
# 0                      1.965725       0.756826     0.058967  ...
# 1                      1.957405       1.108707     1.222531  ...
# 2                      1.943847       1.734370     0.828451  ...
# 3                      1.923226       1.495577     0.753078  ...
# 4                      1.941546       1.416714     1.250196  ...
# ...                         ...            ...          ...  ...
# 7196                  -0.929960      -0.612976    -0.491386  ...
# 7197                  -0.445428      -0.998451    -0.435735  ...
# 7198                  -0.587092      -1.603167    -1.136411  ...
# 7199                  -0.749961       0.675719     0.491015  ...
# 7200                  -0.191294       0.785260     0.624175  ...
#
#       yj_bicycle_perc  yj_on_foot_perc  yj_other_perc  \
# 0            1.275285         2.541451       1.459227
# 1           -0.534930        -0.984309       0.228226
# 2           -1.106924        -0.540533       0.128016
# 3           -0.533747        -0.292659       0.088521
# 4           -0.280787        -0.661333      -2.080410
# ...               ...              ...            ...
# 7196         0.402422         0.322708      -0.454857
# 7197        -0.358857        -1.275943       0.526216
# 7198        -0.957006        -1.279329      -0.045623
# 7199         0.775006         1.401139       0.168965
# 7200         0.988226         1.900336       1.253540
#
#       yj_avg_time_from_origin_car_UNWEIGHTED  yj_avg_time_car  \
# 0                                        NaN         1.481788
# 1                                        NaN        -0.456789
# 2                                        NaN        -0.760907
# 3                                        NaN        -0.555122
# 4                                        NaN        -0.998789
# ...                                      ...              ...
# 7196                                     NaN        -0.265651
# 7197                                     NaN         1.011251
# 7198                                     NaN         1.948483
# 7199                                     NaN         0.601903
# 7200                                     NaN         0.577961
#
#       yj_avg_time_from_origin_bus_UNWEIGHTED  yj_avg_time_bus  \
# 0                                        NaN        -1.337881
# 1                                        NaN         0.386653
# 2                                        NaN         0.414225
# 3                                        NaN        -0.237495
# 4                                        NaN         0.135678
# ...                                      ...              ...
# 7196                                     NaN        -1.214749
# 7197                                     NaN        -0.349478
# 7198                                     NaN         1.184156
# 7199                                     NaN        -1.476719
# 7200                                     NaN        -0.130780
#
#       yj_avg_time_from_origin_rail_UNWEIGHTED  yj_avg_time_rail  yj_car_perc
# 0                                         NaN         -0.941110    -2.112126
# 1                                         NaN         -0.443501    -1.111678
# 2                                         NaN         -0.445279    -1.374803
# 3                                         NaN         -0.514662    -0.963451
# 4                                         NaN         -0.484465    -1.195965
# ...                                       ...               ...          ...
# 7196                                      NaN          1.738647     0.938470
# 7197                                      NaN          1.220594     1.196903
# 7198                                      NaN          2.020649     0.341567
# 7199                                      NaN          1.482596    -0.441150
# 7200                                      NaN          0.625038    -1.135195
#
# [7201 rows x 22 columns]

# %%
# store MSOA column 
MSOA = yj[['MSOA']]

# %%
# drop non numeric columns
yj.drop(['Unnamed: 0', 'MSOA'], axis=1, inplace=True)
yj
# Out:
#       yj_Bus_stops  yj_Train_stations  yj_metro_stations  \
# 0         3.625940           1.820241           3.529935
# 1        -0.963892          -0.579537          -0.283298
# 2        -1.131653          -0.579537          -0.283298
# 3        -1.619346          -0.579537          -0.283298
# 4        -1.980026          -0.579537          -0.283298
# ...            ...                ...                ...
# 7196      1.371322          -0.579537          -0.283298
# 7197      2.438483          -0.579537          -0.283298
# 7198      2.934894          -0.579537           3.529935
# 7199      0.794516          -0.579537          -0.283298
# 7200      0.949971           1.705764          -0.283298
#
#       yj_HH_owning_cars_perc  yj_work_from_home_perc  \
# 0                  -2.078686                1.094545
# 1                  -1.009171               -1.009040
# 2                  -0.623687               -0.780242
# 3                  -0.106580               -1.025167
# 4                  -0.796578               -1.065720
# ...                      ...                     ...
# 7196                0.101249               -0.322619
# 7197                1.144891                0.902061
# 7198                1.093962                1.984056
# 7199                0.433334               -1.183888
# 7200               -0.993786               -1.112405
#
#       yj_underground_metro_perc  yj_train_perc  yj_bus_perc  yj_taxi_perc  \
# 0                      1.965725       0.756826     0.058967      1.186406
# 1                      1.957405       1.108707     1.222531      1.051060
# 2                      1.943847       1.734370     0.828451      0.380373
# 3                      1.923226       1.495577     0.753078      0.804076
# 4                      1.941546       1.416714     1.250196      0.497199
# ...                         ...            ...          ...           ...
# 7196                  -0.929960      -0.612976    -0.491386      1.355409
# 7197                  -0.445428      -0.998451    -0.435735     -0.746744
# 7198                  -0.587092      -1.603167    -1.136411     -0.824609
# 7199                  -0.749961       0.675719     0.491015      0.513920
# 7200                  -0.191294       0.785260     0.624175      0.874077
#
#       yj_motorcycle_perc  yj_bicycle_perc  yj_on_foot_perc  yj_other_perc  \
# 0              -0.839575         1.275285         2.541451       1.459227
# 1               0.498862        -0.534930        -0.984309       0.228226
# 2              -0.053968        -1.106924        -0.540533       0.128016
# 3               0.937380        -0.533747        -0.292659       0.088521
# 4               0.576136        -0.280787        -0.661333      -2.080410
# ...                  ...              ...              ...            ...
# 7196            0.058155         0.402422         0.322708      -0.454857
# 7197           -0.775119        -0.358857        -1.275943       0.526216
# 7198           -0.414835        -0.957006        -1.279329      -0.045623
# 7199           -2.037105         0.775006         1.401139       0.168965
# 7200           -2.497061         0.988226         1.900336       1.253540
#
#       yj_avg_time_from_origin_car_UNWEIGHTED  yj_avg_time_car  \
# 0                                        NaN         1.481788
# 1                                        NaN        -0.456789
# 2                                        NaN        -0.760907
# 3                                        NaN        -0.555122
# 4                                        NaN        -0.998789
# ...                                      ...              ...
# 7196                                     NaN        -0.265651
# 7197                                     NaN         1.011251
# 7198                                     NaN         1.948483
# 7199                                     NaN         0.601903
# 7200                                     NaN         0.577961
#
#       yj_avg_time_from_origin_bus_UNWEIGHTED  yj_avg_time_bus  \
# 0                                        NaN        -1.337881
# 1                                        NaN         0.386653
# 2                                        NaN         0.414225
# 3                                        NaN        -0.237495
# 4                                        NaN         0.135678
# ...                                      ...              ...
# 7196                                     NaN        -1.214749
# 7197                                     NaN        -0.349478
# 7198                                     NaN         1.184156
# 7199                                     NaN        -1.476719
# 7200                                     NaN        -0.130780
#
#       yj_avg_time_from_origin_rail_UNWEIGHTED  yj_avg_time_rail  yj_car_perc
# 0                                         NaN         -0.941110    -2.112126
# 1                                         NaN         -0.443501    -1.111678
# 2                                         NaN         -0.445279    -1.374803
# 3                                         NaN         -0.514662    -0.963451
# 4                                         NaN         -0.484465    -1.195965
# ...                                       ...               ...          ...
# 7196                                      NaN          1.738647     0.938470
# 7197                                      NaN          1.220594     1.196903
# 7198                                      NaN          2.020649     0.341567
# 7199                                      NaN          1.482596    -0.441150
# 7200                                      NaN          0.625038    -1.135195
#
# [7201 rows x 20 columns]

# %%
yj.isna().sum()
# Out:
# yj_Bus_stops                                  0
# yj_Train_stations                             0
# yj_metro_stations                             0
# yj_HH_owning_cars_perc                        0
# yj_work_from_home_perc                        0
# yj_underground_metro_perc                     0
# yj_train_perc                                 0
# yj_bus_perc                                   0
# yj_taxi_perc                                  0
# yj_motorcycle_perc                            0
# yj_bicycle_perc                               0
# yj_on_foot_perc                               0
# yj_other_perc                                 0
# yj_avg_time_from_origin_car_UNWEIGHTED     7201
# yj_avg_time_car                               0
# yj_avg_time_from_origin_bus_UNWEIGHTED     7201
# yj_avg_time_bus                               0
# yj_avg_time_from_origin_rail_UNWEIGHTED    7201
# yj_avg_time_rail                              0
# yj_car_perc                                   0
# dtype: int64

# %%
# drop any columns with NA values
yj.dropna(axis = 1, how = 'any', inplace = True)
yj.isna().sum()
# Out:
# yj_Bus_stops                 0
# yj_Train_stations            0
# yj_metro_stations            0
# yj_HH_owning_cars_perc       0
# yj_work_from_home_perc       0
# yj_underground_metro_perc    0
# yj_train_perc                0
# yj_bus_perc                  0
# yj_taxi_perc                 0
# yj_motorcycle_perc           0
# yj_bicycle_perc              0
# yj_on_foot_perc              0
# yj_other_perc                0
# yj_avg_time_car              0
# yj_avg_time_bus              0
# yj_avg_time_rail             0
# yj_car_perc                  0
# dtype: int64

# %% [markdown]
# ## DBSCAN

# %%
# We need to select the epsilon and min_smaples parameters

# https://towardsdatascience.com/machine-learning-clustering-dbscan-determine-the-optimal-value-for-epsilon-eps-python-example-3100091cfbc
# eps: Two points are considered neighbors if the distance between the two points is below the threshold epsilon.
# min_samples: The minimum number of neighbors a given point should have in order to be classified as a core point. 
from sklearn import neighbors

neigh = neighbors.NearestNeighbors(n_neighbors=2)
nbrs = neigh.fit(yj)
distances, indices = nbrs.kneighbors(yj)
distances
# Out:
# array([[0.        , 2.43581348],
#        [0.        , 1.38032383],
#        [0.        , 1.27460841],
#        ...,
#        [0.        , 2.14755374],
#        [0.        , 2.31262784],
#        [0.        , 2.21896851]])

# %%
# sort and plot the results
distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.plot(distances)

# %%
# create DBSCAN cluster object

# the eps is at the point of maximum curvature in the graph above
dbscan = DBSCAN(eps=2.5, min_samples=5) 

#algorith to be used by the NearestNeighbors module to compute pointwise distance and find neighest neighbours - see NN module documentation
# run the .fit() function on the scaled dataset
dbscan.fit(yj)
# Out:
# DBSCAN(algorithm='auto', eps=2.5, leaf_size=30, metric='euclidean',
#        metric_params=None, min_samples=5, n_jobs=None, p=None)

# %%
#Get the labels from the clusters
dbscan_labels = dbscan.labels_
#dbscan_labels
# to get number of clusters
len(set(dbscan_labels)) - (1 if -1 in dbscan_labels else 0)
# Out:
# 7

# %%
#check the silhouette score
# A silhouette score ranges from -1 to 1, with -1 being the worst score possible and 1 
# being the best score. Silhouette scores of 0 suggest overlapping clusters.
metrics.silhouette_score(yj, dbscan_labels)
# Out:
# 0.07225288167348863

# %%
#assign the labels to the original dataframe
yj_zscore_DB =yj.assign(label = dbscan_labels)

#and check the value counts
yj_zscore_DB.label.value_counts()
# Out:
#  0    6478
#  1     346
# -1     326
#  4      30
#  6       8
#  3       5
#  2       4
#  5       4
# Name: label, dtype: int64

# %%
# re-insert MSOA column
yj_zscore_DB =pd.concat([MSOA, yj_zscore_DB], axis='columns')
#save to csv
yj_zscore_DB.to_csv('Data/Clustering_Results/yeojohnson_zscore_st_DBSCAN.csv')

# %% [markdown]
# ## kmeans clustering

# %%
#elbow plot over multiple k's

#calculate SSE for a range of number of cluster

list_SSE = []
min_k = 1
max_k = 10
range_k = range(min_k, max_k+1)
for i in range_k:
    km = KMeans(
        n_clusters=i, init='random',
        n_init=10, max_iter=300,
        tol=1e-04, random_state=0
    )
    km.fit(yj)
    # inertia is a concept in physics. Roughly it means SSE of clustering.
    list_SSE.append(km.inertia_)

# plot
plt.plot(range_k, list_SSE, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('SSE')
plt.show()

# %%
#set the number of clusters to explore
k_cluster = 3
#set the random seed
random_seed = 1
#random state: int, default = None
#determines random number generation for ecntroid intialisation, use an int to make the randomness deterministic

# %%
#get the method for kmeans
kmeans_method = KMeans(n_clusters=k_cluster,random_state=random_seed)
#apply the fit to the scaled dataset
kmeans_method.fit(yj)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=1, tol=0.0001, verbose=0)

# %%
#assign the labels to original databse
yj_zscore_kmeans = yj.assign(label = kmeans_method.labels_)

# %%
# re-insert MSOA column
yj_zscore_kmeans =pd.concat([MSOA, yj_zscore_kmeans], axis='columns')
#save to csv
yj_zscore_kmeans.to_csv('Data/Clustering_Results/yeojohnson_zscore_st_kmeans.csv')

# %%
#silhouette score over multiple k's

#empty array to hold the silhouette scores
silhouette = []

#iterate over the number of clusters from 2 to 10
for i in range(2, 10):
    #create an empty array to store the average
    average = []
    #repeat the kmeans clustering 10 times
    for x in range(1, 10):
        #setting the number of clusters as i
        k_cluster = i
        #create a random integer for the random seed
        random_seed = random.randint(1,101)
        #run the kmeans analysis
        kmeans_method = KMeans(n_clusters=k_cluster,random_state=random_seed)
        #fit it to the scaled dataset
        kmeans_method.fit(yj)
        #get the labels
        labels = kmeans_method.labels_
        #get the silhouette score
        a = metrics.silhouette_score(yj, labels)
        #append it to the average list
        average.append(a)
    #get the silhouette score and append it to the silhouette 
    silhouette.append(sum(average)/len(average))
    
#plot the silhouette score
plt.plot(silhouette)

# %% [markdown]
# ## Agglomerative clustering

# %%
#set the number of clusters expected (from elbow diagram in kmeans part)
n_clusters = 3

#get the hierarchy method
hierarchy = AgglomerativeClustering(n_clusters = n_clusters)

#fit it to the data
hierarchy.fit(yj)
# Out:
# AgglomerativeClustering(affinity='euclidean', compute_full_tree='auto',
#                         connectivity=None, distance_threshold=None,
#                         linkage='ward', memory=None, n_clusters=3,
#                         pooling_func='deprecated')

# %%
#assign labels to the original data
yj_zscore_hierarchy = yj.assign(label = hierarchy.labels_)

# %%
hierarchy_labels = hierarchy.labels_

#check the silhouette score
metrics.silhouette_score(yj, hierarchy_labels)
# Out:
# 0.1264765650391077

# %%
# re-insert MSOA column
yj_zscore_hierarchy =pd.concat([MSOA, yj_zscore_hierarchy], axis='columns')
#save to csv
yj_zscore_hierarchy.to_csv('Data/Clustering_Results/yeojohnson_zscore_st_heirarchy.csv')

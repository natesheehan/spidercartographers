# %%
#get the current working directory 
import os

os.getcwd()
# Out:
# '/Users/Hussein/Documents/Code Repos/spidercartographers/Scripts'

# %%
#importing pandas
import pandas as pd
import matplotlib.pyplot as plt

# %%
#reading in the cleaned transport csv
cleaned = pd.read_csv("Data/cleaned_transport.csv")

# %%
#checking for NaNs
cleaned.isna().sum()
# Out:
# MSOA                                      0
# HH_owning_cars_perc                       0
# work_from_home_perc                       0
# underground_metro_perc                    0
# train_perc                                0
# bus_perc                                  0
# bicycle_perc                              0
# on_foot_perc                              0
# avg_time_from_origin_car_UNWEIGHTED       0
# avg_time_car                              0
# avg_time_from_origin_bus_UNWEIGHTED       0
# avg_time_bus                              0
# avg_time_from_origin_rail_UNWEIGHTED      0
# avg_time_rail                           600
# car_perc                                  0
# dtype: int64

# %%
#checking the count of each variable
cleaned.count()
# Out:
# MSOA                                    7201
# HH_owning_cars_perc                     7201
# work_from_home_perc                     7201
# underground_metro_perc                  7201
# train_perc                              7201
# bus_perc                                7201
# bicycle_perc                            7201
# on_foot_perc                            7201
# avg_time_from_origin_car_UNWEIGHTED     7201
# avg_time_car                            7201
# avg_time_from_origin_bus_UNWEIGHTED     7201
# avg_time_bus                            7201
# avg_time_from_origin_rail_UNWEIGHTED    7201
# avg_time_rail                           6601
# car_perc                                7201
# dtype: int64

# %%
#filling the nas in place
cleaned = cleaned.fillna(0)

# %%
#describing the data 
cleaned.describe()
# Out:
#        HH_owning_cars_perc  work_from_home_perc  underground_metro_perc  \
# count          7201.000000          7201.000000             7201.000000
# mean             74.960857            10.381327                3.366972
# std              14.805855             4.826474                8.826858
# min              17.510217             2.826552                0.000000
# 25%              66.484375             7.034728                0.067981
# 50%              78.173077             8.896122                0.154979
# 75%              86.843177            12.367384                0.538761
# max              97.078464            37.591728               55.726092
#
#         train_perc     bus_perc  bicycle_perc  on_foot_perc  \
# count  7201.000000  7201.000000   7201.000000   7201.000000
# mean      4.705109     7.309413      2.681102      9.768108
# std       6.114003     6.356014      2.609434      6.457069
# min       0.052521     0.173671      0.080678      1.495132
# 25%       1.024378     2.491103      1.144674      5.330564
# 50%       2.332223     5.378328      1.879947      7.910112
# 75%       5.741775    10.130410      3.293135     12.098765
# max      46.028513    45.517755     33.739166     51.324141
#
#        avg_time_from_origin_car_UNWEIGHTED  avg_time_car  \
# count                          7201.000000   7201.000000
# mean                            130.591022     12.017846
# std                              31.007922      3.510609
# min                              93.756273      4.963508
# 25%                             107.624737      9.595475
# 50%                             123.443394     11.205226
# 75%                             143.197178     13.592524
# max                             451.015245     64.233607
#
#        avg_time_from_origin_bus_UNWEIGHTED  avg_time_bus  \
# count                          7201.000000   7201.000000
# mean                            287.737317     28.790735
# std                              62.516604      9.827288
# min                             186.393862      9.321269
# 25%                             241.643744     22.919591
# 50%                             273.252282     27.004106
# 75%                             321.465236     32.122061
# max                             716.459160    115.176372
#
#        avg_time_from_origin_rail_UNWEIGHTED  avg_time_rail     car_perc
# count                           7201.000000    7201.000000  7201.000000
# mean                             157.361110      62.055411    60.009764
# std                               41.168636      55.418017    16.491918
# min                              101.793289       0.000000     3.051202
# 25%                              127.907208      20.846716    54.508453
# 50%                              147.594086      45.288792    65.107577
# 75%                              175.665069      89.160227    71.104748
# max                              437.669204     346.818133    84.167759

# %%
#checking the types of the data
cleaned.dtypes
# Out:
# MSOA                                     object
# HH_owning_cars_perc                     float64
# work_from_home_perc                     float64
# underground_metro_perc                  float64
# train_perc                              float64
# bus_perc                                float64
# bicycle_perc                            float64
# on_foot_perc                            float64
# avg_time_from_origin_car_UNWEIGHTED     float64
# avg_time_car                            float64
# avg_time_from_origin_bus_UNWEIGHTED     float64
# avg_time_bus                            float64
# avg_time_from_origin_rail_UNWEIGHTED    float64
# avg_time_rail                           float64
# car_perc                                float64
# dtype: object

# %%
# #plotting all the distributions of the each of the variables
# #looks like most of them are positively skewed and could be amenable to log transformation

# import matplotlib.pyplot as plt
# import seaborn as sns

# f, axes = plt.subplots(4,5, figsize = (20,20), sharex=False)


# sns.distplot(cleaned["Bus_stops"], ax=axes[0,0])
# sns.distplot(cleaned["Train_stations"], ax=axes[0,1])
# sns.distplot(cleaned["metro_stations"], ax=axes[0,2])
# sns.distplot(cleaned["HH_owning_cars_perc"], ax=axes[0,3])
# sns.distplot(cleaned["work_from_home_perc"], ax=axes[0,4])
# sns.distplot(cleaned["underground_metro_perc"], ax=axes[1,0])
# sns.distplot(cleaned["train_perc"], ax=axes[1,1])
# sns.distplot(cleaned["bus_perc"], ax=axes[1,2])
# sns.distplot(cleaned["taxi_perc"], ax=axes[1,4])
# sns.distplot(cleaned["motorcycle_perc"], ax=axes[2,0])
# sns.distplot(cleaned["bicycle_perc"], ax=axes[2,1])
# sns.distplot(cleaned["on_foot_perc"], ax=axes[2,2])
# sns.distplot(cleaned["other_perc"], ax=axes[2,3])
# sns.distplot(cleaned["avg_time_car"], ax=axes[2,4])
# sns.distplot(cleaned["avg_time_bus"], ax=axes[3,0])
# sns.distplot(cleaned["avg_time_rail"], ax=axes[3,1])
# sns.distplot(cleaned["car_perc"], ax=axes[3,2])

# %%
#before transforming drop the MSOA column
#create a new dataframe so retain the original MSOA column
cleaned1 = cleaned.drop(["MSOA"], axis = 1 )

# %%
#cleaning them by log transformation

import numpy as np

for column in cleaned1.columns:
    try:
        cleaned1[column] = np.log10(cleaned1[column])
    except (ValueError, AttributeError):
        pass
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/series.py:679: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
#log does not work with 0's for which there were many
#therefore replace any infinity values with 0 again afterwards
cleaned1 = cleaned1.replace([np.inf, -np.inf], 0)

# %%
# #plot the resulting distributions using the same as before
# f, axes = plt.subplots(4,5, figsize = (20,20), sharex=False)


# sns.distplot(cleaned1["Bus_stops"], ax=axes[0,0])
# sns.distplot(cleaned1["Train_stations"], ax=axes[0,1])
# sns.distplot(cleaned1["metro_stations"], ax=axes[0,2])
# sns.distplot(cleaned1["HH_owning_cars_perc"], ax=axes[0,3])
# sns.distplot(cleaned1["work_from_home_perc"], ax=axes[0,4])
# sns.distplot(cleaned1["underground_metro_perc"], ax=axes[1,0])
# sns.distplot(cleaned1["train_perc"], ax=axes[1,1])
# sns.distplot(cleaned1["bus_perc"], ax=axes[1,2])
# sns.distplot(cleaned1["taxi_perc"], ax=axes[1,4])
# sns.distplot(cleaned1["motorcycle_perc"], ax=axes[2,0])
# sns.distplot(cleaned1["bicycle_perc"], ax=axes[2,1])
# sns.distplot(cleaned1["on_foot_perc"], ax=axes[2,2])
# sns.distplot(cleaned1["other_perc"], ax=axes[2,3])
# sns.distplot(cleaned1["avg_time_car"], ax=axes[2,4])
# sns.distplot(cleaned1["avg_time_bus"], ax=axes[3,0])
# sns.distplot(cleaned1["avg_time_rail"], ax=axes[3,1])
# sns.distplot(cleaned1["car_perc"], ax=axes[3,2])

# %%
# plot
cleaned1.hist(layout=(5, 4), figsize=(40, 30), color='orange', alpha=.5);
#plt.savefig("Plots/log_transformed_Histograms.png")

# %%
#add the MSOA value back in
cleaned1["MSOA"] = cleaned["MSOA"]

# %%
#check to see what the outcome looks like
cleaned1
# Out:
#       HH_owning_cars_perc  work_from_home_perc  underground_metro_perc  \
# 0                1.485783             1.165836                1.264601
# 1                1.795207             0.806246                1.194798
# 2                1.837623             0.838584                1.106468
# 3                1.880892             0.804009                1.006336
# 4                1.820003             0.798410                1.093636
# ...                   ...                  ...                     ...
# 7196             1.895392             0.907075               -1.673850
# 7197             1.952917             1.125100               -0.827692
# 7198             1.950550             1.391915               -0.969183
# 7199             1.916086             0.782284               -1.192382
# 7200             1.797139             0.792005               -0.631241
#
#       train_perc  bus_perc  bicycle_perc  on_foot_perc  \
# 0       0.735091  0.743364      0.705724      1.659371
# 1       0.914479  1.168329      0.123362      0.669306
# 2       1.297765  1.026087     -0.054900      0.771175
# 3       1.138330  0.998783      0.123721      0.829495
# 4       1.089723  1.178300      0.200176      0.743154
# ...          ...       ...           ...           ...
# 7196    0.111480  0.530270      0.408935      0.980327
# 7197   -0.079504  0.552519      0.176629      0.603671
# 7198   -0.468581  0.252666     -0.006971      0.602914
# 7199    0.695985  0.903369      0.529154      1.275473
# 7200    0.748970  0.951958      0.601755      1.431717
#
#       avg_time_from_origin_car_UNWEIGHTED  avg_time_car  \
# 0                                2.029944      1.241501
# 1                                2.055951      1.005614
# 2                                2.055328      0.976930
# 3                                2.067944      0.996164
# 4                                2.056996      0.955545
# ...                                   ...           ...
# 7196                             2.190299      1.024494
# 7197                             2.117793      1.172967
# 7198                             2.262545      1.320936
# 7199                             2.165896      1.120355
# 7200                             2.162969      1.117446
#
#       avg_time_from_origin_bus_UNWEIGHTED  avg_time_bus  \
# 0                                2.363348      1.273601
# 1                                2.439025      1.481029
# 2                                2.438108      1.484693
# 3                                2.443860      1.401313
# 4                                2.438778      1.448256
# ...                                   ...           ...
# 7196                             2.577693      1.287184
# 7197                             2.507309      1.387616
# 7198                             2.564395      1.592522
# 7199                             2.505142      1.258478
# 7200                             2.500262      1.414529
#
#       avg_time_from_origin_rail_UNWEIGHTED  avg_time_rail  car_perc       MSOA
# 0                                 2.029358       1.121770  0.484471  E02000001
# 1                                 2.093391       1.443412  1.670428  E02000002
# 2                                 2.088203       1.442417  1.617429  E02000003
# 3                                 2.095575       1.402876  1.694387  E02000004
# 4                                 2.087746       1.420261  1.655154  E02000005
# ...                                    ...            ...       ...        ...
# 7196                              2.265699       2.270247  1.863213  W02000419
# 7197                              2.237624       2.121276  1.877230  W02000420
# 7198                              2.449417       2.343915  1.825654  W02000421
# 7199                              2.281636       2.199022  1.759280  W02000422
# 7200                              2.278585       1.922114  1.666301  W02000423
#
# [7201 rows x 15 columns]

# %%
#output the results to a csv
cleaned1.to_csv("Data/transport_log_transform.csv", index=False)

# %%
#running the next stage which is the standardisation
#drop the MSOA value again

cleaned1.drop(["MSOA"], axis = 1, inplace = True)

# %%
#get the columns names to then re-add to the numpy array
column_names = list(cleaned1.columns)

# %%
#use the preprocessing function which does a normal standardisation


import sklearn.preprocessing as preprocessing

#this takes arguments: X ,axis = 0, with_mean = True, with_std = True, copy = True
#X is the data to centre and scale
#axs: int (0 by default) - axis used to compute means and Std along, if 0  independentky
#standardise each feature, other (if 1) standardize each sample
#with_mean: boolean, True by default, if true centre the data before scaling
#with_std: boolean, True by default, if True scale the data to unit variance
#copy: boolean, optional, default True, set to False to perform inplace row normalisation and avoid a copy

#NaNs are treated as missing values: disregarded

scaled = preprocessing.scale(cleaned1) # add your dataframe name here

#this creates a numpy array
scaled
# Out:
# array([[-3.74748834,  1.06377697,  2.01944168, ..., -1.53579348,
#         -0.71951652, -6.66446346],
#        [-0.6848153 , -0.9690509 ,  1.93829976, ..., -0.90125201,
#         -0.17410886, -0.4133832 ],
#        [-0.26498761, -0.78623504,  1.83562063, ..., -0.9526686 ,
#         -0.17579533, -0.69273914],
#        ...,
#        [ 0.8527678 ,  2.34184105, -0.57721205, ...,  2.62679892,
#          1.35287279,  0.40479716],
#        [ 0.51164444, -1.10451186, -0.8366686 , ...,  0.9641671 ,
#          1.10717837,  0.05494583],
#        [-0.66568957, -1.04955457, -0.18437249, ...,  0.93393467,
#          0.63762617, -0.43513751]])

# %%
#transform the numpy array back into a dataframe
log_then_normal = pd.DataFrame(scaled)

# %%
#add back the columns names stored before

log_then_normal.columns = column_names

# %%
#add back the MSOA columns
log_then_normal["MSOA"] = cleaned["MSOA"]

# %%
#write the resulting output to a csv
log_then_normal.to_csv("Data/transport_log_then_normal.csv", index=False)

# %%
scaled
# Out:
# array([[-3.74748834,  1.06377697,  2.01944168, ..., -1.53579348,
#         -0.71951652, -6.66446346],
#        [-0.6848153 , -0.9690509 ,  1.93829976, ..., -0.90125201,
#         -0.17410886, -0.4133832 ],
#        [-0.26498761, -0.78623504,  1.83562063, ..., -0.9526686 ,
#         -0.17579533, -0.69273914],
#        ...,
#        [ 0.8527678 ,  2.34184105, -0.57721205, ...,  2.62679892,
#          1.35287279,  0.40479716],
#        [ 0.51164444, -1.10451186, -0.8366686 , ...,  0.9641671 ,
#          1.10717837,  0.05494583],
#        [-0.66568957, -1.04955457, -0.18437249, ...,  0.93393467,
#          0.63762617, -0.43513751]])

# %% [markdown]
# ## range standardisation

# %%
#transform df to np array
cleaned_array = cleaned1.values

#range standardisation
min_max_scaler = preprocessing.MinMaxScaler()
min_max_scaled = min_max_scaler.fit_transform(cleaned_array)
# transform to dataframe
range_standardized = pd.DataFrame(min_max_scaled, columns=column_names)
range_standardized
# Out:
#       HH_owning_cars_perc  work_from_home_perc  underground_metro_perc  \
# 0                0.326003             0.635840                0.869858
# 1                0.741990             0.315872                0.850990
# 2                0.799013             0.344648                0.827113
# 3                0.857185             0.313882                0.800047
# 4                0.775325             0.308900                0.823645
# ...                   ...                  ...                     ...
# 7196             0.876678             0.405591                0.075570
# 7197             0.954013             0.599592                0.304294
# 7198             0.950832             0.837007                0.266048
# 7199             0.904499             0.294551                0.205715
# 7200             0.744588             0.303201                0.357396
#
#       train_perc  bus_perc  bicycle_perc  on_foot_perc  \
# 0       0.684665  0.621735      0.686268      0.966821
# 1       0.745625  0.797453      0.464110      0.322098
# 2       0.875875  0.738637      0.396107      0.388434
# 3       0.821695  0.727347      0.464247      0.426412
# 4       0.805177  0.801575      0.493413      0.370187
# ...          ...       ...           ...           ...
# 7196    0.472746  0.533623      0.573050      0.524632
# 7197    0.407845  0.542823      0.484430      0.279357
# 7198    0.275627  0.418837      0.414390      0.278863
# 7199    0.671375  0.687895      0.618911      0.716829
# 7200    0.689381  0.707986      0.646606      0.818575
#
#       avg_time_from_origin_car_UNWEIGHTED  avg_time_car  \
# 0                                0.084938      0.490760
# 1                                0.123060      0.278626
# 2                                0.122148      0.252831
# 3                                0.140640      0.270128
# 4                                0.124593      0.233599
# ...                                   ...           ...
# 7196                             0.319997      0.295605
# 7197                             0.213713      0.429127
# 7198                             0.425899      0.562196
# 7199                             0.284225      0.381813
# 7200                             0.279934      0.379197
#
#       avg_time_from_origin_bus_UNWEIGHTED  avg_time_bus  \
# 0                                0.158897      0.278532
# 1                                0.288312      0.468504
# 2                                0.286744      0.471859
# 3                                0.296580      0.395497
# 4                                0.287889      0.438489
# ...                                   ...           ...
# 7196                             0.525450      0.290972
# 7197                             0.405086      0.382952
# 7198                             0.502707      0.570614
# 7199                             0.401380      0.264682
# 7200                             0.393033      0.407601
#
#       avg_time_from_origin_rail_UNWEIGHTED  avg_time_rail  car_perc
# 0                                 0.034161       0.492702  0.000000
# 1                                 0.135252       0.607745  0.823196
# 2                                 0.127060       0.607389  0.786408
# 3                                 0.138699       0.593246  0.839826
# 4                                 0.126340       0.599464  0.812594
# ...                                    ...            ...       ...
# 7196                              0.407276       0.903480  0.957011
# 7197                              0.362953       0.850198  0.966741
# 7198                              0.697314       0.929830  0.930941
# 7199                              0.432436       0.878005  0.884869
# 7200                              0.427620       0.778963  0.820331
#
# [7201 rows x 14 columns]

# %%
#then add the MSOA column
range_standardized["MSOA"] = cleaned["MSOA"]

range_standardized
# Out:
#       HH_owning_cars_perc  work_from_home_perc  underground_metro_perc  \
# 0                0.326003             0.635840                0.869858
# 1                0.741990             0.315872                0.850990
# 2                0.799013             0.344648                0.827113
# 3                0.857185             0.313882                0.800047
# 4                0.775325             0.308900                0.823645
# ...                   ...                  ...                     ...
# 7196             0.876678             0.405591                0.075570
# 7197             0.954013             0.599592                0.304294
# 7198             0.950832             0.837007                0.266048
# 7199             0.904499             0.294551                0.205715
# 7200             0.744588             0.303201                0.357396
#
#       train_perc  bus_perc  bicycle_perc  on_foot_perc  \
# 0       0.684665  0.621735      0.686268      0.966821
# 1       0.745625  0.797453      0.464110      0.322098
# 2       0.875875  0.738637      0.396107      0.388434
# 3       0.821695  0.727347      0.464247      0.426412
# 4       0.805177  0.801575      0.493413      0.370187
# ...          ...       ...           ...           ...
# 7196    0.472746  0.533623      0.573050      0.524632
# 7197    0.407845  0.542823      0.484430      0.279357
# 7198    0.275627  0.418837      0.414390      0.278863
# 7199    0.671375  0.687895      0.618911      0.716829
# 7200    0.689381  0.707986      0.646606      0.818575
#
#       avg_time_from_origin_car_UNWEIGHTED  avg_time_car  \
# 0                                0.084938      0.490760
# 1                                0.123060      0.278626
# 2                                0.122148      0.252831
# 3                                0.140640      0.270128
# 4                                0.124593      0.233599
# ...                                   ...           ...
# 7196                             0.319997      0.295605
# 7197                             0.213713      0.429127
# 7198                             0.425899      0.562196
# 7199                             0.284225      0.381813
# 7200                             0.279934      0.379197
#
#       avg_time_from_origin_bus_UNWEIGHTED  avg_time_bus  \
# 0                                0.158897      0.278532
# 1                                0.288312      0.468504
# 2                                0.286744      0.471859
# 3                                0.296580      0.395497
# 4                                0.287889      0.438489
# ...                                   ...           ...
# 7196                             0.525450      0.290972
# 7197                             0.405086      0.382952
# 7198                             0.502707      0.570614
# 7199                             0.401380      0.264682
# 7200                             0.393033      0.407601
#
#       avg_time_from_origin_rail_UNWEIGHTED  avg_time_rail  car_perc       MSOA
# 0                                 0.034161       0.492702  0.000000  E02000001
# 1                                 0.135252       0.607745  0.823196  E02000002
# 2                                 0.127060       0.607389  0.786408  E02000003
# 3                                 0.138699       0.593246  0.839826  E02000004
# 4                                 0.126340       0.599464  0.812594  E02000005
# ...                                    ...            ...       ...        ...
# 7196                              0.407276       0.903480  0.957011  W02000419
# 7197                              0.362953       0.850198  0.966741  W02000420
# 7198                              0.697314       0.929830  0.930941  W02000421
# 7199                              0.432436       0.878005  0.884869  W02000422
# 7200                              0.427620       0.778963  0.820331  W02000423
#
# [7201 rows x 15 columns]

# %%
range_standardized.to_csv("Data/transport_log_then_range.csv", index=False)

# %% [markdown]
# ## interdecile

# %%
from sklearn.preprocessing import RobustScaler

# we change the range because the default is iqr (0.25 - 0.75)
idr = RobustScaler(quantile_range = (0.1,0.9))

# Transform the 'yj_transformed' df
idr_mat = idr.fit_transform(cleaned_array)
idr_mat
# Out:
# array([[-4.54610577,  3.21187499, 24.13014004, ..., -9.27657146,
#         -4.02426423, -7.12131673],
#        [-1.09222864, -2.11947913, 23.28754423, ..., -5.02487213,
#         -1.60134898, -0.76724877],
#        [-0.61877515, -1.6400209 , 22.22130133, ..., -5.36938525,
#         -1.60884095, -1.05120715],
#        ...,
#        [ 0.6417544 ,  6.56376342, -2.83409112, ..., 18.61457839,
#          5.18210381,  0.06441127],
#        [ 0.25705836, -2.47474304, -5.5283458 , ...,  7.47423388,
#          4.09063262, -0.29120392],
#        [-1.07065993, -2.33061045,  1.24524243, ...,  7.27166368,
#          2.00469713, -0.78936148]])

# %%
# transform to a df
idr_scaled = pd.DataFrame(idr_mat, columns=column_names)
idr_scaled
# Out:
#       HH_owning_cars_perc  work_from_home_perc  underground_metro_perc  \
# 0               -4.546106             3.211875               24.130140
# 1               -1.092229            -2.119479               23.287544
# 2               -0.618775            -1.640021               22.221301
# 3               -0.135786            -2.152636               21.012597
# 4               -0.815455            -2.235657               22.066407
# ...                   ...                  ...                     ...
# 7196             0.026061            -0.624563              -11.340200
# 7197             0.668167             2.607917               -1.126144
# 7198             0.641754             6.563763               -2.834091
# 7199             0.257058            -2.474743               -5.528346
# 7200            -1.070660            -2.330610                1.245242
#
#       train_perc  bus_perc  bicycle_perc  on_foot_perc  \
# 0       1.014552  0.068626      1.382841      5.924758
# 1       1.510024  2.361978     -0.483132     -1.781474
# 2       2.568671  1.594357     -1.054311     -0.988576
# 3       2.128309  1.447008     -0.481981     -0.534634
# 4       1.994055  2.415786     -0.237010     -1.206674
# ...          ...       ...           ...           ...
# 7196   -0.707881 -1.081348      0.431886      0.639373
# 7197   -1.235384 -0.961280     -0.312457     -2.292347
# 7198   -2.310024 -2.579455     -0.900740     -2.298244
# 7199    0.906539  0.932101      0.817085      2.936665
# 7200    1.052886  1.194316      1.049709      4.152801
#
#       avg_time_from_origin_car_UNWEIGHTED  avg_time_car  \
# 0                               -9.697685      3.017386
# 1                               -5.598392     -0.688157
# 2                               -5.696521     -1.138749
# 3                               -3.707987     -0.836599
# 4                               -5.433586     -1.474691
# ...                                   ...           ...
# 7196                            15.578412     -0.391570
# 7197                             4.149563      1.940779
# 7198                            26.966130      4.265214
# 7199                            11.731811      1.114300
# 7200                            11.270409      1.068607
#
#       avg_time_from_origin_bus_UNWEIGHTED  avg_time_bus  \
# 0                               -4.615036     -1.686968
# 1                                0.155128      0.530151
# 2                                0.097319      0.569303
# 3                                0.459884     -0.321904
# 4                                0.139540      0.179852
# ...                                   ...           ...
# 7196                             8.895862     -1.541784
# 7197                             4.459327     -0.468306
# 7198                             8.057596      1.721847
# 7199                             4.322726     -1.848609
# 7200                             4.015082     -0.180642
#
#       avg_time_from_origin_rail_UNWEIGHTED  avg_time_rail  car_perc
# 0                                -9.276571      -4.024264 -7.121317
# 1                                -5.024872      -1.601349 -0.767249
# 2                                -5.369385      -1.608841 -1.051207
# 3                                -4.879861      -1.906700 -0.638882
# 4                                -5.399683      -1.775744 -0.849081
# ...                                    ...            ...       ...
# 7196                              6.416051       4.627164  0.265646
# 7197                              4.551903       3.504974  0.340745
# 7198                             18.614578       5.182104  0.064411
# 7199                              7.474234       4.090633 -0.291204
# 7200                              7.271664       2.004697 -0.789361
#
# [7201 rows x 14 columns]

# %%
idr_scaled["MSOA"] = cleaned["MSOA"]

idr_scaled.head()
# Out:
#    HH_owning_cars_perc  work_from_home_perc  underground_metro_perc  \
# 0            -4.546106             3.211875               24.130140
# 1            -1.092229            -2.119479               23.287544
# 2            -0.618775            -1.640021               22.221301
# 3            -0.135786            -2.152636               21.012597
# 4            -0.815455            -2.235657               22.066407
#
#    train_perc  bus_perc  bicycle_perc  on_foot_perc  \
# 0    1.014552  0.068626      1.382841      5.924758
# 1    1.510024  2.361978     -0.483132     -1.781474
# 2    2.568671  1.594357     -1.054311     -0.988576
# 3    2.128309  1.447008     -0.481981     -0.534634
# 4    1.994055  2.415786     -0.237010     -1.206674
#
#    avg_time_from_origin_car_UNWEIGHTED  avg_time_car  \
# 0                            -9.697685      3.017386
# 1                            -5.598392     -0.688157
# 2                            -5.696521     -1.138749
# 3                            -3.707987     -0.836599
# 4                            -5.433586     -1.474691
#
#    avg_time_from_origin_bus_UNWEIGHTED  avg_time_bus  \
# 0                            -4.615036     -1.686968
# 1                             0.155128      0.530151
# 2                             0.097319      0.569303
# 3                             0.459884     -0.321904
# 4                             0.139540      0.179852
#
#    avg_time_from_origin_rail_UNWEIGHTED  avg_time_rail  car_perc       MSOA
# 0                             -9.276571      -4.024264 -7.121317  E02000001
# 1                             -5.024872      -1.601349 -0.767249  E02000002
# 2                             -5.369385      -1.608841 -1.051207  E02000003
# 3                             -4.879861      -1.906700 -0.638882  E02000004
# 4                             -5.399683      -1.775744 -0.849081  E02000005

# %%
#save to csv
idr_scaled.to_csv('Data/transport_log_then_idr.csv')
